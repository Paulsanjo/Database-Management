# %% [markdown]
# # Assignmnet 1 DBMS INFO-6210
#
# ## The dataset selected is: Common Airline Customer Service Utterances
# It is a sample dataset created by CrowdFlower at https://www.crowdflower.com/wp-content/uploads/2017/11/Utterance-Flights-f1197494.csv on various customer service scenarios.

# %% [markdown]
# ## Importing all dependencies

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
from scipy import stats
import seaborn as sns
from datetime import datetime
import sqlite3

# %% [markdown]
# # Reading data using pandas library

# %%
flight_data = pd.read_csv('flight_data.csv')

# %%
flight_data.head() #Printing the data
# Out:
#       UNIT ID      CREATED AT          ID      STARTED AT  TAINTED    CHANNEL  \
# 0  1403461953  10-11-17 22:56  2909781477  10-11-17 22:46    False  clixsense
# 1  1403461975  10-11-17 22:56  2909781471  10-11-17 22:46    False  clixsense
# 2  1403461968  10-11-17 22:32  2909750917  10-11-17 22:23    False  clixsense
# 3  1403461973  10-11-17 22:32  2909750911  10-11-17 22:23    False  clixsense
# 4  1403461959  10-11-17 22:56  2909781476  10-11-17 22:46    False  clixsense
#
#    CHANNEL_ID  TRUST  WORKER ID COUNTRY REGION    CITY            IP  \
# 0           1      1   39347443     AUT      9  Vienna  80.110.82.64
# 1           1      1   39347443     AUT      9  Vienna  80.110.82.64
# 2           1      1   39347443     AUT      9  Vienna  80.110.82.64
# 3           1      1   39347443     AUT      9  Vienna  80.110.82.64
# 4           1      1   39347443     AUT      9  Vienna  80.110.82.64
#
#                                           RESPONSE 1  \
# 0  I have some health problems, is it possible to...
# 1  Could you please check the direct flights to m...
# 2  I think my bag is to heavy, what is the maximu...
# 3       I am injured, could you get me a wheelchair?
# 4  Could you please tell me my frequent flier num...
#
#                                           RESPONSE 2  \
# 0  I'm stuck in heavy traffic, can I change my fl...
# 1  I need a direct flight to my location, do you ...
# 2        What is the maximum weight for checked bag?
# 3  I can't get out on my own, I would like a whee...
# 4  What type of ID do you need to tell me my freq...
#
#                                           RESPONSE 3  \
# 0  I forgot my passport, could you change my flig...
# 1          Do you fly directly maybe to my location?
# 2  I have more space in my bag, what is the maxim...
# 3                Is it possible to get a wheelchair?
# 4  I have lost my frequent flier number, could yo...
#
#                                             SCENARIO  COMPOSITE_KEY
# 0                     You need to change your flight           28.0
# 1  You need to check if there are any direct flig...           28.0
# 2  You need to know the maximum weight for a chec...           28.0
# 3     You need to request a wheelchair when you land           28.0
# 4                You need your frequent flier number           28.0

# %%
flight_data.isnull().sum() #Checking all the null values
# Out:
# UNIT ID            0
# CREATED AT         0
# ID                 0
# STARTED AT         0
# TAINTED            0
# CHANNEL            0
# CHANNEL_ID         0
# TRUST              0
# WORKER ID          0
# COUNTRY            0
# REGION           165
# CITY             165
# IP                 0
# RESPONSE 1         0
# RESPONSE 2         1
# RESPONSE 3         0
# SCENARIO           8
# COMPOSITE_KEY    165
# dtype: int64

# %% [markdown]
# ## We now clean and reformat the data to fit the database schema
#
# The data contains many NULL values and a few columns which are redundant and are not needed to be stored in our database. In the following clleaning comands we shall take care of them and fit our data to the SQL schema we have designed.

# %%
flight_data.drop(['CREATED AT', 'STARTED AT', 'TRUST', 'TAINTED'], axis=1, inplace = True) #Droping all the redundant attributes

# %%
flight_data = flight_data.dropna() #Removing all the NUll values

# %%
flight_data.isnull().sum() #Checking for any NULL values
# Out:
# UNIT ID          0
# ID               0
# CHANNEL          0
# CHANNEL_ID       0
# WORKER ID        0
# COUNTRY          0
# REGION           0
# CITY             0
# IP               0
# RESPONSE 1       0
# RESPONSE 2       0
# RESPONSE 3       0
# SCENARIO         0
# COMPOSITE_KEY    0
# dtype: int64

# %% [markdown]
# The data as we see has no null values and the redundant rows have been removed too, thus we can say that the data is complete, consistant and uniform. Thus, we can store this dataset into a database using SQLite3.

# %% [markdown]
# ## Formating the strings to same cases
#
# This makes the storage into the databases easier.

# %%
flight_data = flight_data.apply(lambda x: x.astype(str).str.lower())
flight_data.head()
# Out:
#       UNIT ID          ID    CHANNEL CHANNEL_ID WORKER ID COUNTRY REGION  \
# 0  1403461953  2909781477  clixsense          1  39347443     aut      9
# 1  1403461975  2909781471  clixsense          1  39347443     aut      9
# 2  1403461968  2909750917  clixsense          1  39347443     aut      9
# 3  1403461973  2909750911  clixsense          1  39347443     aut      9
# 4  1403461959  2909781476  clixsense          1  39347443     aut      9
#
#      CITY            IP                                         RESPONSE 1  \
# 0  vienna  80.110.82.64  i have some health problems, is it possible to...
# 1  vienna  80.110.82.64  could you please check the direct flights to m...
# 2  vienna  80.110.82.64  i think my bag is to heavy, what is the maximu...
# 3  vienna  80.110.82.64       i am injured, could you get me a wheelchair?
# 4  vienna  80.110.82.64  could you please tell me my frequent flier num...
#
#                                           RESPONSE 2  \
# 0  i'm stuck in heavy traffic, can i change my fl...
# 1  i need a direct flight to my location, do you ...
# 2        what is the maximum weight for checked bag?
# 3  i can't get out on my own, i would like a whee...
# 4  what type of id do you need to tell me my freq...
#
#                                           RESPONSE 3  \
# 0  i forgot my passport, could you change my flig...
# 1          do you fly directly maybe to my location?
# 2  i have more space in my bag, what is the maxim...
# 3                is it possible to get a wheelchair?
# 4  i have lost my frequent flier number, could yo...
#
#                                             SCENARIO COMPOSITE_KEY
# 0                     you need to change your flight          28.0
# 1  you need to check if there are any direct flig...          28.0
# 2  you need to know the maximum weight for a chec...          28.0
# 3     you need to request a wheelchair when you land          28.0
# 4                you need your frequent flier number          28.0

# %% [markdown]
# ## Creating a connection to the database

# %%
conn = sqlite3.connect("FlightSurvey.db") #connects to a database named "FlightSurvey"

# %%
c = conn.cursor()

# %% [markdown]
# ## Splitting data into various tables (Normalizing Data)

# %% [markdown]
# # Table1: Customer response (Main Table)

# %%
cust_responses = pd.DataFrame()
cust_responses[['RESPONSE_ID','RESPONSE_1','RESPONSE_2','RESPONSE_3','UNIT_ID','WORKER_ID','CHANNEL_ID','REGION_ID']] = flight_data[['ID', 'RESPONSE 1', 'RESPONSE 2', 'RESPONSE 3', 'UNIT ID', 'WORKER ID','CHANNEL_ID','COMPOSITE_KEY']]
cust_responses.head()
# Out:
#   RESPONSE_ID                                         RESPONSE_1  \
# 0  2909781477  i have some health problems, is it possible to...
# 1  2909781471  could you please check the direct flights to m...
# 2  2909750917  i think my bag is to heavy, what is the maximu...
# 3  2909750911       i am injured, could you get me a wheelchair?
# 4  2909781476  could you please tell me my frequent flier num...
#
#                                           RESPONSE_2  \
# 0  i'm stuck in heavy traffic, can i change my fl...
# 1  i need a direct flight to my location, do you ...
# 2        what is the maximum weight for checked bag?
# 3  i can't get out on my own, i would like a whee...
# 4  what type of id do you need to tell me my freq...
#
#                                           RESPONSE_3     UNIT_ID WORKER_ID  \
# 0  i forgot my passport, could you change my flig...  1403461953  39347443
# 1          do you fly directly maybe to my location?  1403461975  39347443
# 2  i have more space in my bag, what is the maxim...  1403461968  39347443
# 3                is it possible to get a wheelchair?  1403461973  39347443
# 4  i have lost my frequent flier number, could yo...  1403461959  39347443
#
#   CHANNEL_ID REGION_ID
# 0          1      28.0
# 1          1      28.0
# 2          1      28.0
# 3          1      28.0
# 4          1      28.0

# %% [markdown]
# # Table2: Scenarios (Dependency)

# %%
scenarios = pd.DataFrame()
scenarios[['SCENARIO_ID','SCENARIO']] = flight_data[['UNIT ID', 'SCENARIO']]
scenarios = scenarios.drop_duplicates() #dropping duplicates
scenarios.head()
# Out:
#   SCENARIO_ID                                           SCENARIO
# 0  1403461953                     you need to change your flight
# 1  1403461975  you need to check if there are any direct flig...
# 2  1403461968  you need to know the maximum weight for a chec...
# 3  1403461973     you need to request a wheelchair when you land
# 4  1403461959                you need your frequent flier number

# %% [markdown]
# # Table3 : Workers (Dependency)

# %%
workers = pd.DataFrame()
workers[['WORKER_ID','IP']] = flight_data[['WORKER ID','IP']]
workers = workers.drop_duplicates() #eliminating duplicates
workers.head()
# Out:
#    WORKER_ID               IP
# 0   39347443     80.110.82.64
# 10  38372558  200.163.232.161
# 12  43125727    179.180.13.10
# 13  43847563      138.0.21.97
# 14  43853403   179.158.154.94

# %% [markdown]
# #  Table4: Channel (Dependency)

# %%
channel = pd.DataFrame()
channel[['CHANNEL_ID','CHANNEL']] = flight_data[['CHANNEL_ID','CHANNEL']]
channel = channel.drop_duplicates()
channel
# Out:
#     CHANNEL_ID         CHANNEL
# 0            1       clixsense
# 10           2          neodev
# 12           3           elite
# 50           4         prodege
# 691          5      bitcoinget
# 776          6  gifthunterclub

# %% [markdown]
# # Table5: Regions (Dependency)

# %%
region = pd.DataFrame()
region[['REGION_ID','COUNTRY','CITY','REGION']] = flight_data[['COMPOSITE_KEY','COUNTRY','CITY','REGION']]
region = region.drop_duplicates()
region.head()
# Out:
#    REGION_ID COUNTRY            CITY REGION
# 0       28.0     aut          vienna      9
# 10      56.0     bra         goiania     29
# 12      57.0     bra          recife     30
# 13      20.0     bra        juazeiro      5
# 14      50.0     bra  rio de janeiro     21

# %% [markdown]
# # Creating the SQL tables
#
# Now that we have normalized our flat file completely, we can store the tables as SQL tables in the database

# %% [markdown]
# ## Table1 to SQL (Primary table with all the Primary and Foreign keys)

# %%
c.execute("""drop table cust_responses""")
c.execute("""CREATE TABLE cust_responses(
response_id INTEGER PRIMARY KEY,
response_1 CHAR(150),
response_2 CHAR(150),
response_3 CHAR(150),
unit_id INTEGER FOREGION KEY,
worker_id INTEGER FOREGION KEY,
channel_id INTEGER FOREGION KEY,
region_id INTEGER FOREGION KEY);""") #Creating the new table and defining the schema

# %% [markdown]
# ## We start to define the schema for the various tables

# %%
cust_responses.to_sql("cust_responses", conn, if_exists = "append", index = False) #Storing data frame to SQL database

# %%
pd.read_sql_query("""select * from cust_responses;""", conn).head() #Querying the database for data
# Out:
#    response_id                              response_1  \
# 0   2909628960  are taxis available to book right now?
# 1   2909628961  are taxis available to book right now?
# 2   2909628963  are taxis available to book right now?
# 3   2909628964  are taxis available to book right now?
# 4   2909628965  are taxis available to book right now?
#
#                                response_2  \
# 0  are taxis available to book right now?
# 1  are taxis available to book right now?
# 2  are taxis available to book right now?
# 3  are taxis available to book right now?
# 4  are taxis available to book right now?
#
#                                response_3     unit_id  worker_id  channel_id  \
# 0  are taxis available to book right now?  1403461960   43650485           2
# 1  are taxis available to book right now?  1403461972   43650485           2
# 2  are taxis available to book right now?  1403461979   43650485           2
# 3  are taxis available to book right now?  1403461970   43650485           2
# 4  are taxis available to book right now?  1403461964   43650485           2
#
#    region_id
# 0         31
# 1         31
# 2         31
# 3         31
# 4         31

# %% [markdown]
# # Table2 to SQL (Dependent table)

# %%
c.execute("""drop table scenarios""")
c.execute("""CREATE TABLE scenarios(
scenario_id INTEGER PRIMARY KEY,
scenario CHAR(150));""")

# %%
scenarios.to_sql("scenarios", conn, if_exists = "append", index = False)
pd.read_sql_query("""select * from scenarios;""", conn).head()
# Out:
#    scenario_id                                           scenario
# 0   1403461952                                 your bag was lost
# 1   1403461953                     you need to change your flight
# 2   1403461954  you want to know if it costs money to bring a ...
# 3   1403461955      you had a bad flight and want some money back
# 4   1403461956                     you want to cancel your flight

# %% [markdown]
# ## Table3 to SQL (Dependent table)

# %%
c.execute("""drop table channel""")
c.execute("""CREATE TABLE channel(
channel_id INTEGER PRIMARY KEY,
channel CHAR(20));""")

# %%
channel.to_sql("channel", conn, if_exists = "append", index = False)
pd.read_sql_query("""select * from channel;""", conn)
# Out:
#    channel_id         channel
# 0           1       clixsense
# 1           2          neodev
# 2           3           elite
# 3           4         prodege
# 4           5      bitcoinget
# 5           6  gifthunterclub

# %% [markdown]
# ## Table4 to SQL (Dependent table)

# %%
c.execute("""drop table region""")
c.execute("""CREATE TABLE region(
region_id INTEGER PRIMARY KEY,
country CHAR(20),
city CHAR(20),
region CHAR(5));""")

# %%
region.to_sql("region", conn, if_exists = "append", index = False)
pd.read_sql_query("""select * from region;""", conn).head()
# Out:
#    region_id country      city region
# 0         11     mne     budva      0
# 1         12     srb  belgrade      0
# 2         13     cri    grecia      1
# 3         14     gha     accra      1
# 4         15     col  medellín      2

# %% [markdown]
# ## Table5 to SQL (Dependent table)

# %%
c.execute("""drop table workers""")
c.execute("""CREATE TABLE workers(
worker_id INTEGER PRIMARY KEY,
ip CHAR(20));""")

# %%
workers.to_sql("workers", conn, if_exists = "append", index = False)
pd.read_sql_query("""select * from workers;""", conn).head()
# Out:
#    worker_id              ip
# 0    5551648  173.183.76.192
# 1   10422922     39.48.57.27
# 2   12291277   78.62.238.184
# 3   21764533     78.2.113.83
# 4   32512686   200.93.70.139

# %% [markdown]
# # Usecases

# %% [markdown]
# ## Executing the SELECT - FROM - WHERE query

# %%
pd.read_sql_query("""SELECT response_1, scenario FROM cust_responses AS c, scenarios AS s WHERE c.unit_id = s.scenario_id;""",conn).head()
# Out:
#                                response_1  \
# 0  are taxis available to book right now?
# 1  are taxis available to book right now?
# 2  are taxis available to book right now?
# 3  are taxis available to book right now?
# 4  are taxis available to book right now?
#
#                                             scenario
# 0  you want to know how much it’s going to cost t...
# 1  you’re worried about the weather and its impli...
# 2  you want to add travel insurance to a purchase...
# 3  you are threatening to never to use this airli...
# 4                     you need to change your flight

# %% [markdown]
# ## Executing the SELECT - FROM - WHERE-LIMIT query

# %%
pd.read_sql_query("""SELECT response_1, response_2, scenario FROM cust_responses AS c, scenarios AS s WHERE c.unit_id = s.scenario_id LIMIT 10;""",conn)
# Out:
#                                           response_1  \
# 0             are taxis available to book right now?
# 1             are taxis available to book right now?
# 2             are taxis available to book right now?
# 3             are taxis available to book right now?
# 4             are taxis available to book right now?
# 5                            can i change the date ?
# 6  there is a travel advisory in the place you’re...
# 7                  can you help me get a new flight?
# 8                  can you help me get a new flight?
# 9                  can you help me get a new flight?
#
#                                           response_2  \
# 0             are taxis available to book right now?
# 1             are taxis available to book right now?
# 2             are taxis available to book right now?
# 3             are taxis available to book right now?
# 4             are taxis available to book right now?
# 5                            can i change the date ?
# 6  there is a travel advisory in the place you’re...
# 7                  can you help me get a new flight?
# 8                  can you help me get a new flight?
# 9                  can you help me get a new flight?
#
#                                             scenario
# 0  you want to know how much it’s going to cost t...
# 1  you’re worried about the weather and its impli...
# 2  you want to add travel insurance to a purchase...
# 3  you are threatening to never to use this airli...
# 4                     you need to change your flight
# 5  you booked a flight for the wrong day and need...
# 6  you need to see if there is a travel advisory ...
# 7  your flight was cancelled and you need to get ...
# 8                     you want to cancel your flight
# 9        you want to check if your flight is on time

# %% [markdown]
# ## Executing a simple JOIN using SELECT - FROM - WHERE query
#
# The number of rows returned is 1025 which is the same as the number of rows in the orignal flat table. This signifies that the normalization is perfect.

# %%
pd.read_sql_query("""SELECT * FROM cust_responses AS c, scenarios AS s, workers AS w, channel AS ch, region AS r WHERE c.unit_id = s.scenario_id AND c.worker_id = w.worker_id AND c.channel_id = ch.channel_id AND c.region_id = r.region_id;""",conn)
# Out:
#       response_id                                         response_1  \
# 0      2909628960             are taxis available to book right now?
# 1      2909628961             are taxis available to book right now?
# 2      2909628963             are taxis available to book right now?
# 3      2909628964             are taxis available to book right now?
# 4      2909628965             are taxis available to book right now?
# 5      2909631961                            can i change the date ?
# 6      2909631963  there is a travel advisory in the place you’re...
# 7      2909631966                  can you help me get a new flight?
# 8      2909631968                  can you help me get a new flight?
# 9      2909631969                  can you help me get a new flight?
# 10     2909632179                           i have to change my fly?
# 11     2909632180             i have to my add fly travel insurance?
# 12     2909632181                 how much money if i change my fly?
# 13     2909632182     i dont what to fly this airfly, what happened?
# 14     2909632183                                  what happen air ?
# 15     2909632675                                         gdfnshjfdh
# 16     2909632676                                       rerhrtntwrht
# 17     2909632677                                       qrqrtqtrtqrq
# 18     2909632678                                      agrgasdfgsfsz
# 19     2909632679                                         gsgsegwaga
# 20     2909633372                  can you help me get a new flight?
# 21     2909633374                  can you help me get a new flight?
# 22     2909633376                  can you help me get a new flight?
# 23     2909633378                  can you help me get a new flight?
# 24     2909633380                  can you help me get a new flight?
# 25     2909633394                                     sgasgsdfgasdga
# 26     2909633399                                         sdgdgsdgdg
# 27     2909633403                                     asgdsgsdagasdg
# 28     2909633408                                         dgsdgasdag
# 29     2909633411                                      sdagdsgadsgds
# ...           ...                                                ...
# 995    2909821453            can you help me find my luggage  please
# 996    2909821455                    i had a bad flight i need money
# 997    2909829787  are there any avaiable flights to my destination?
# 998    2909829791                  what is my frequent flier number?
# 999    2909829795                          what are my meal options?
# 1000   2909829797                           where can i find my bag?
# 1001   2909829800                  i need to get a different flight.
# 1002   2909831114  i wanted to know the maximum weight of hold lu...
# 1003   2909831115  sorry, i would like to know the price for bagg...
# 1004   2909831116             i'm sorry i listened to what you said.
# 1005   2909831117   i want to request a wheelchair for the disabled.
# 1006   2909831118    i want to change the list of the booked flight.
# 1007   2909833598                        already found my luggage ??
# 1008   2909833601              i need to know another flight option?
# 1009   2909833604  i would like to know if i could take my pet on...
# 1010   2909833607       it was bad, i'm coming back, i need a refund
# 1011   2909833611                                    i need a refund
# 1012   2909834954    are there any direct flights to my destination?
# 1013   2909834958       i need to change my flight. can you help me?
# 1014   2909834963   do you have a membership program and can i join?
# 1015   2909834965             what food will be served on the plane?
# 1016   2909834966  do you have a lost & found department? i lost ...
# 1017   2909882924  how dangerous is traveling with the weather li...
# 1018   2909882930  i would like to know what is the price for a f...
# 1019   2909882934        is there availability to change my flight ?
# 1020   2909924372                           when is the next flight?
# 1021   2909924373                                   what time is it?
# 1022   2909924374                        how can i cancel my flight?
# 1023   2909924375                              i need another ticker
# 1024   2909924376                  you know about a travel advisory?
#
#                                              response_2  \
# 0                are taxis available to book right now?
# 1                are taxis available to book right now?
# 2                are taxis available to book right now?
# 3                are taxis available to book right now?
# 4                are taxis available to book right now?
# 5                               can i change the date ?
# 6     there is a travel advisory in the place you’re...
# 7                     can you help me get a new flight?
# 8                     can you help me get a new flight?
# 9                     can you help me get a new flight?
# 10                  and also i have to change my chair?
# 11    i have to my add fly travel insurance? and wha...
# 12    how much money if i change my fly? what will h...
# 13    i dont what to fly this airfly, what happened?...
# 14                    what happen air ? if i don't fly?
# 15                                         fsfssfnbfnfb
# 16                                         ererqrtrqttq
# 17                                        rtq4t35634trg
# 18                                        sagegaerarggs
# 19                                          agewgawageg
# 20                    can you help me get a new flight?
# 21                    can you help me get a new flight?
# 22                    can you help me get a new flight?
# 23                    can you help me get a new flight?
# 24                    can you help me get a new flight?
# 25                                      sdgsdgasdgsdgsd
# 26                                         agdsgsdgdsga
# 27                                            asdgdsgds
# 28                                             sgdsgdsg
# 29                                            asgdgdsag
# ...                                                 ...
# 995                i really need my luggage, thank you.
# 996        real mente tuve un mal vuelo necesito dinero
# 997                 find direct flights to my location.
# 998   what's my member number for frequent flier miles?
# 999                                what is on the menu?
# 1000                           where is lost and found?
# 1001                           how do i change flights?
# 1002                 what is the weight of one luggage?
# 1003                      how much baggage one luggage?
# 1004                             could you repeat that?
# 1005  you can upon landing to provide me with the wh...
# 1006           you can add in flight, often flying man?
# 1007            it is important that i count my luggage
# 1008    is there another available if i miss my flight?
# 1009                           are there any drawbacks?
# 1010      paid for a good flight and was poor attention
# 1011  it is not fair to pay for good attention and t...
# 1012     do you have a direct flight to place im going?
# 1013  is there a possibility to change my flight for...
# 1014   i need a frequent flier number, can you help me?
# 1015  where can i get an information on a plane menu...
# 1016         i lost my bag on a plane. can you help me?
# 1017  if it is safe to travel with the weather as we...
# 1018                if they work with flight insurance?
# 1019                         i need to change my flight
# 1020      can i buy another ticket for the next flight?
# 1021          there is no porblem with my flight right?
# 1022                        if i cancel i get a refund?
# 1023                            can i change my ticket?
# 1024         i need a travel advisory, you can help me?
#
#                                              response_3     unit_id  \
# 0                are taxis available to book right now?  1403461960
# 1                are taxis available to book right now?  1403461972
# 2                are taxis available to book right now?  1403461979
# 3                are taxis available to book right now?  1403461970
# 4                are taxis available to book right now?  1403461964
# 5                               can i change the date ?  1403461974
# 6     there is a travel advisory in the place you’re...  1403461976
# 7                     can you help me get a new flight?  1403461962
# 8                     can you help me get a new flight?  1403461956
# 9                     can you help me get a new flight?  1403461957
# 10                   what happened if i changed my fly?  1403461964
# 11    i have to my add fly travel insurance if or re...  1403461979
# 12    how much money if i change my fly? if i accept...  1403461960
# 13    i dont what to fly this airfly, what happened?...  1403461970
# 14                               what happened air fly?  1403461972
# 15                                          fgffsehetea  1403461974
# 16                                          qtrrqtqeqet  1403461962
# 17                                        reghetherahet  1403461956
# 18                                         gwgawerrgrga  1403461957
# 19                                      agrgragarwgwega  1403461976
# 20                    can you help me get a new flight?  1403461971
# 21                    can you help me get a new flight?  1403461969
# 22                    can you help me get a new flight?  1403461961
# 23                    can you help me get a new flight?  1403461965
# 24                    can you help me get a new flight?  1403461980
# 25                                   gsdgasdgsdgaasdgss  1403461980
# 26                                        asgdsgsdagdgs  1403461969
# 27                                           gsdgdgdgds  1403461961
# 28                                             dgdsgdgs  1403461965
# 29                                            asdgdsgsd  1403461971
# ...                                                 ...         ...
# 995   i need to have my luggage lost so i can get to...  1403461967
# 996                                  i need money to go  1403461955
# 997          can i get a flight to my location nonstop?  1403461975
# 998   i don't have my frequent flier number what is it?  1403461959
# 999                           what is available to eat?  1403461963
# 1000               how can i file a lost baggage claim?  1403461952
# 1001                        i need an alternate flight.  1403461953
# 1002                       how much luggage can i take?  1403461968
# 1003          does the weight of luggage for the price?  1403461954
# 1004                               thanks for repeating  1403461977
# 1005   somebody can help me with a wheelchair, stroller  1403461973
# 1006          how much will it cost to change the list?  1403461981
# 1007                                      has to appear  1403461967
# 1008        i appreciate if you look for another option  1403461966
# 1009                    or where you could take my pet?  1403461978
# 1010               they gave me nothing to eat or drink  1403461955
# 1011                                      refund please  1403461958
# 1012        is there a direct flight to my destination?  1403461975
# 1013  can you change my flight for another and what ...  1403461953
# 1014  how can i get a frequent flier number from you...  1403461959
# 1015        do you know what is on a menu on my flight?  1403461963
# 1016  i lost my bag on a plane. what i must do to tr...  1403461952
# 1017  i do not think it's convenient to travel like ...  1403461972
# 1018                       i only travel with insurance  1403461979
# 1019  i do not want to travel now with the weather s...  1403461964
# 1020            are you going to refund my money right?  1403461962
# 1021                              my flight is on time?  1403461957
# 1022                      can i speak with the manager?  1403461956
# 1023                        i need another fligh please  1403461974
# 1024                        where is a traver advisory?  1403461976
#
#       worker_id  channel_id  region_id  scenario_id  \
# 0      43650485           2         31   1403461960
# 1      43650485           2         31   1403461972
# 2      43650485           2         31   1403461979
# 3      43650485           2         31   1403461970
# 4      43650485           2         31   1403461964
# 5      43650485           2         31   1403461974
# 6      43650485           2         31   1403461976
# 7      43650485           2         31   1403461962
# 8      43650485           2         31   1403461956
# 9      43650485           2         31   1403461957
# 10     42740374           2         65   1403461964
# 11     42740374           2         65   1403461979
# 12     42740374           2         65   1403461960
# 13     42740374           2         65   1403461970
# 14     42740374           2         65   1403461972
# 15     43765666           2         26   1403461974
# 16     43765666           2         26   1403461962
# 17     43765666           2         26   1403461956
# 18     43765666           2         26   1403461957
# 19     43765666           2         26   1403461976
# 20     43650485           2         31   1403461971
# 21     43650485           2         31   1403461969
# 22     43650485           2         31   1403461961
# 23     43650485           2         31   1403461965
# 24     43650485           2         31   1403461980
# 25     43765666           2         26   1403461980
# 26     43765666           2         26   1403461969
# 27     43765666           2         26   1403461961
# 28     43765666           2         26   1403461965
# 29     43765666           2         26   1403461971
# ...         ...         ...        ...          ...
# 995    43908741           3         55   1403461967
# 996    43908741           3         55   1403461955
# 997    38202325           4         69   1403461975
# 998    38202325           4         69   1403461959
# 999    38202325           4         69   1403461963
# 1000   38202325           4         69   1403461952
# 1001   38202325           4         69   1403461953
# 1002   39767721           1         66   1403461968
# 1003   39767721           1         66   1403461954
# 1004   39767721           1         66   1403461977
# 1005   39767721           1         66   1403461973
# 1006   39767721           1         66   1403461981
# 1007   43825606           2         39   1403461967
# 1008   43825606           2         39   1403461966
# 1009   43825606           2         39   1403461978
# 1010   43825606           2         39   1403461955
# 1011   43825606           2         39   1403461958
# 1012   21764533           1         34   1403461975
# 1013   21764533           1         34   1403461953
# 1014   21764533           1         34   1403461959
# 1015   21764533           1         34   1403461963
# 1016   21764533           1         34   1403461952
# 1017   43825606           2         39   1403461972
# 1018   43825606           2         39   1403461979
# 1019   43825606           2         39   1403461964
# 1020   43690074           2         55   1403461962
# 1021   43690074           2         55   1403461957
# 1022   43690074           2         55   1403461956
# 1023   43690074           2         55   1403461974
# 1024   43690074           2         55   1403461976
#
#                                                scenario  worker_id  \
# 0     you want to know how much it’s going to cost t...   43650485
# 1     you’re worried about the weather and its impli...   43650485
# 2     you want to add travel insurance to a purchase...   43650485
# 3     you are threatening to never to use this airli...   43650485
# 4                        you need to change your flight   43650485
# 5     you booked a flight for the wrong day and need...   43650485
# 6     you need to see if there is a travel advisory ...   43650485
# 7     your flight was cancelled and you need to get ...   43650485
# 8                        you want to cancel your flight   43650485
# 9           you want to check if your flight is on time   43650485
# 10                       you need to change your flight   42740374
# 11    you want to add travel insurance to a purchase...   42740374
# 12    you want to know how much it’s going to cost t...   42740374
# 13    you are threatening to never to use this airli...   42740374
# 14    you’re worried about the weather and its impli...   42740374
# 15    you booked a flight for the wrong day and need...   43765666
# 16    your flight was cancelled and you need to get ...   43765666
# 17                       you want to cancel your flight   43765666
# 18          you want to check if your flight is on time   43765666
# 19    you need to see if there is a travel advisory ...   43765666
# 20        you want to see if there’s wifi on the flight   43650485
# 21    you missed a very important flight and need on...   43650485
# 22                            you want to book a flight   43650485
# 23                 you want to check your flight status   43650485
# 24     you want to sign up for a frequent flyer program   43650485
# 25     you want to sign up for a frequent flyer program   43765666
# 26    you missed a very important flight and need on...   43765666
# 27                            you want to book a flight   43765666
# 28                 you want to check your flight status   43765666
# 29        you want to see if there’s wifi on the flight   43765666
# ...                                                 ...        ...
# 995   you’re checking if the airline has found your ...   43908741
# 996       you had a bad flight and want some money back   43908741
# 997   you need to check if there are any direct flig...   38202325
# 998                 you need your frequent flier number   38202325
# 999   you want to know what food will be served on t...   38202325
# 1000                                 your bag was lost    38202325
# 1001                     you need to change your flight   38202325
# 1002  you need to know the maximum weight for a chec...   39767721
# 1003  you want to know if it costs money to bring a ...   39767721
# 1004  you want a customer service agent to repeat wh...   39767721
# 1005     you need to request a wheelchair when you land   39767721
# 1006  you want to add a frequent flyer number to a f...   39767721
# 1007  you’re checking if the airline has found your ...   43825606
# 1008  you’re going to miss your connecting flight an...   43825606
# 1009  you want to see if you can bring your pet on t...   43825606
# 1010      you had a bad flight and want some money back   43825606
# 1011                                  you want a refund   43825606
# 1012  you need to check if there are any direct flig...   21764533
# 1013                     you need to change your flight   21764533
# 1014                you need your frequent flier number   21764533
# 1015  you want to know what food will be served on t...   21764533
# 1016                                 your bag was lost    21764533
# 1017  you’re worried about the weather and its impli...   43825606
# 1018  you want to add travel insurance to a purchase...   43825606
# 1019                     you need to change your flight   43825606
# 1020  your flight was cancelled and you need to get ...   43690074
# 1021        you want to check if your flight is on time   43690074
# 1022                     you want to cancel your flight   43690074
# 1023  you booked a flight for the wrong day and need...   43690074
# 1024  you need to see if there is a travel advisory ...   43690074
#
#                    ip  channel_id    channel  region_id country          city  \
# 0      156.211.251.26           2     neodev         31     egy         cairo
# 1      156.211.251.26           2     neodev         31     egy         cairo
# 2      156.211.251.26           2     neodev         31     egy         cairo
# 3      156.211.251.26           2     neodev         31     egy         cairo
# 4      156.211.251.26           2     neodev         31     egy         cairo
# 5      156.211.251.26           2     neodev         31     egy         cairo
# 6      156.211.251.26           2     neodev         31     egy         cairo
# 7      156.211.251.26           2     neodev         31     egy         cairo
# 8      156.211.251.26           2     neodev         31     egy         cairo
# 9      156.211.251.26           2     neodev         31     egy         cairo
# 10      176.88.29.229           2     neodev         65     tur        ankara
# 11      176.88.29.229           2     neodev         65     tur        ankara
# 12      176.88.29.229           2     neodev         65     tur        ankara
# 13      176.88.29.229           2     neodev         65     tur        ankara
# 14      176.88.29.229           2     neodev         65     tur        ankara
# 15      186.89.123.89           2     neodev         26     ven       guacara
# 16      186.89.123.89           2     neodev         26     ven       guacara
# 17      186.89.123.89           2     neodev         26     ven       guacara
# 18      186.89.123.89           2     neodev         26     ven       guacara
# 19      186.89.123.89           2     neodev         26     ven       guacara
# 20     156.211.251.26           2     neodev         31     egy         cairo
# 21     156.211.251.26           2     neodev         31     egy         cairo
# 22     156.211.251.26           2     neodev         31     egy         cairo
# 23     156.211.251.26           2     neodev         31     egy         cairo
# 24     156.211.251.26           2     neodev         31     egy         cairo
# 25      186.89.123.89           2     neodev         26     ven       guacara
# 26      186.89.123.89           2     neodev         26     ven       guacara
# 27      186.89.123.89           2     neodev         26     ven       guacara
# 28      186.89.123.89           2     neodev         26     ven       guacara
# 29      186.89.123.89           2     neodev         26     ven       guacara
# ...               ...         ...        ...        ...     ...           ...
# 995    190.203.210.88           3      elite         55     ven       caracas
# 996    190.203.210.88           3      elite         55     ven       caracas
# 997      98.13.82.121           4    prodege         69     usa       caribou
# 998      98.13.82.121           4    prodege         69     usa       caribou
# 999      98.13.82.121           4    prodege         69     usa       caribou
# 1000     98.13.82.121           4    prodege         69     usa       caribou
# 1001     98.13.82.121           4    prodege         69     usa       caribou
# 1002  188.162.195.224           1  clixsense         66     rus         kazan
# 1003  188.162.195.224           1  clixsense         66     rus         kazan
# 1004  188.162.195.224           1  clixsense         66     rus         kazan
# 1005  188.162.195.224           1  clixsense         66     rus         kazan
# 1006  188.162.195.224           1  clixsense         66     rus         kazan
# 1007    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1008    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1009    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1010    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1011    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1012      78.2.113.83           1  clixsense         34     hrv        rijeka
# 1013      78.2.113.83           1  clixsense         34     hrv        rijeka
# 1014      78.2.113.83           1  clixsense         34     hrv        rijeka
# 1015      78.2.113.83           1  clixsense         34     hrv        rijeka
# 1016      78.2.113.83           1  clixsense         34     hrv        rijeka
# 1017    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1018    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1019    201.249.96.90           2     neodev         39     ven  barquisimeto
# 1020    186.188.70.36           2     neodev         55     ven       caracas
# 1021    186.188.70.36           2     neodev         55     ven       caracas
# 1022    186.188.70.36           2     neodev         55     ven       caracas
# 1023    186.188.70.36           2     neodev         55     ven       caracas
# 1024    186.188.70.36           2     neodev         55     ven       caracas
#
#      region
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
# 5        11
# 6        11
# 7        11
# 8        11
# 9        11
# 10       68
# 11       68
# 12       68
# 13       68
# 14       68
# 15        7
# 16        7
# 17        7
# 18        7
# 19        7
# 20       11
# 21       11
# 22       11
# 23       11
# 24       11
# 25        7
# 26        7
# 27        7
# 28        7
# 29        7
# ...     ...
# 995      25
# 996      25
# 997      me
# 998      me
# 999      me
# 1000     me
# 1001     me
# 1002     73
# 1003     73
# 1004     73
# 1005     73
# 1006     73
# 1007     13
# 1008     13
# 1009     13
# 1010     13
# 1011     13
# 1012     12
# 1013     12
# 1014     12
# 1015     12
# 1016     12
# 1017     13
# 1018     13
# 1019     13
# 1020     25
# 1021     25
# 1022     25
# 1023     25
# 1024     25
#
# [1025 rows x 18 columns]

# %% [markdown]
# ## Executing a query using INNER JOIN (two tables)

# %%
pd.read_sql_query("""SELECT response_1, channel FROM cust_responses AS c INNER JOIN channel AS ch ON c.channel_id = ch.channel_id;""", conn).head()
# Out:
#                                response_1 channel
# 0  are taxis available to book right now?  neodev
# 1  are taxis available to book right now?  neodev
# 2  are taxis available to book right now?  neodev
# 3  are taxis available to book right now?  neodev
# 4  are taxis available to book right now?  neodev

# %% [markdown]
# ## Executing a query using LEFT OUTER JOIN (two tables)

# %%
pd.read_sql_query("""SELECT response_1, channel FROM cust_responses AS c LEFT JOIN channel AS ch ON c.channel_id = ch.channel_id;""", conn).head()
# Out:
#                                response_1 channel
# 0  are taxis available to book right now?  neodev
# 1  are taxis available to book right now?  neodev
# 2  are taxis available to book right now?  neodev
# 3  are taxis available to book right now?  neodev
# 4  are taxis available to book right now?  neodev

# %% [markdown]
# ## Executing the query using LEFT OUTER JOIN (three tables)

# %%
pd.read_sql_query("""SELECT response_1, channel, ip FROM cust_responses AS c LEFT JOIN channel AS ch, workers AS w ON c.channel_id = ch.channel_id AND c.worker_id = w. worker_id;""", conn).head()
# Out:
#                                response_1 channel              ip
# 0  are taxis available to book right now?  neodev  156.211.251.26
# 1  are taxis available to book right now?  neodev  156.211.251.26
# 2  are taxis available to book right now?  neodev  156.211.251.26
# 3  are taxis available to book right now?  neodev  156.211.251.26
# 4  are taxis available to book right now?  neodev  156.211.251.26

# %% [markdown]
# ## Executing query using INNER JOIN (three tables)

# %%
pd.read_sql_query("""SELECT response_1, channel, country FROM cust_responses AS c INNER JOIN channel AS ch, region AS r ON c.channel_id = ch.channel_id AND c.region_id = r.region_id ;""", conn).head()
# Out:
#                                response_1 channel country
# 0  are taxis available to book right now?  neodev     egy
# 1  are taxis available to book right now?  neodev     egy
# 2  are taxis available to book right now?  neodev     egy
# 3  are taxis available to book right now?  neodev     egy
# 4  are taxis available to book right now?  neodev     egy

# %% [markdown]
# ## ~**No support for  RIGHT OUTER and FULL JOINS in SQLite in python*~

# %% [markdown]
# ## Executing INNER JOIN on all the tables

# %%
pd.read_sql_query("""SELECT * FROM cust_responses AS c INNER JOIN channel AS ch, region AS r, scenarios AS s, workers AS w ON c.worker_id = w.worker_id AND c.unit_id = s.scenario_id AND c.channel_id = ch. channel_id AND c.region_id = r.region_id; """,conn).head()
# Out:
#    response_id                              response_1  \
# 0   2909628960  are taxis available to book right now?
# 1   2909628961  are taxis available to book right now?
# 2   2909628963  are taxis available to book right now?
# 3   2909628964  are taxis available to book right now?
# 4   2909628965  are taxis available to book right now?
#
#                                response_2  \
# 0  are taxis available to book right now?
# 1  are taxis available to book right now?
# 2  are taxis available to book right now?
# 3  are taxis available to book right now?
# 4  are taxis available to book right now?
#
#                                response_3     unit_id  worker_id  channel_id  \
# 0  are taxis available to book right now?  1403461960   43650485           2
# 1  are taxis available to book right now?  1403461972   43650485           2
# 2  are taxis available to book right now?  1403461979   43650485           2
# 3  are taxis available to book right now?  1403461970   43650485           2
# 4  are taxis available to book right now?  1403461964   43650485           2
#
#    region_id  channel_id channel  region_id country   city region  \
# 0         31           2  neodev         31     egy  cairo     11
# 1         31           2  neodev         31     egy  cairo     11
# 2         31           2  neodev         31     egy  cairo     11
# 3         31           2  neodev         31     egy  cairo     11
# 4         31           2  neodev         31     egy  cairo     11
#
#    scenario_id                                           scenario  worker_id  \
# 0   1403461960  you want to know how much it’s going to cost t...   43650485
# 1   1403461972  you’re worried about the weather and its impli...   43650485
# 2   1403461979  you want to add travel insurance to a purchase...   43650485
# 3   1403461970  you are threatening to never to use this airli...   43650485
# 4   1403461964                     you need to change your flight   43650485
#
#                ip
# 0  156.211.251.26
# 1  156.211.251.26
# 2  156.211.251.26
# 3  156.211.251.26
# 4  156.211.251.26

# %%
conn.commit()
conn.close()

# %% [markdown]
# I have shown various usecases in the exampples above. The schema of the given database is such that there is only one parent table which has 4 connected child tables. The parent table has the primary keys of the child table as foreign keys.
